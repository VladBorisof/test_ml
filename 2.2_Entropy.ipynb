# %%
import math as m

# %%
E_sh_0 = - (1/1)*m.log2(1/1) - 0
E_sh_1 = - (4/9)*m.log2(4/9) - (5/9)*m.log2(5/9)

# %%
E_sh_0, E_sh_1
# Out:
# (-0.0, 0.9910760598382222)

# %%
E_gav_0 = - (5/5)*m.log2(5/5) - 0
E_gav_1 = - (4/5)*m.log2(4/5) - (1/5)*m.log2(1/5)

# %%
E_gav_0,\
E_gav_1
# Out:
# (-0.0, 0.7219280948873623)

# %%
E_laz_0 = - (4/4)*m.log(4/4) - 0
E_laz_1 = - (6/6)*m.log(6/6) - 0

# %%
E_laz_0,\
E_laz_1
# Out:
# (-0.0, -0.0)

# %%
e = -(4/10)*m.log2(4/10) - (6/10)*m.log2(6/10)
e
# Out:
# 0.9709505944546686

# %%
IG_1 = e - ((1/10) * E_sh_0 + (9/10) * E_sh_1)
IG_2 = e - ((5/10) * E_gav_0 + (5/10) * E_gav_1)
IG_3 = e - ((4/10) * E_laz_0 + (6/10) * E_laz_1)

# %%
print('{:0.2f} {:0.2f} {:0.2f}'.format(IG_1, IG_2, IG_3))
# Out:
# 0.08 0.61 0.97
