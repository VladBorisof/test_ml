# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv("StudentsPerformance.csv")

# %%
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.iloc[:3, :5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
students_performance_w = students_performance.iloc[[0, 3, 4, 7, 8]]

# %%
students_performance_w.index = ["Lox", "pi", "dor", "nanna", "sdds"]

# %%
students_performance_w
# Out:
#        gender race/ethnicity parental level of education         lunch  \
# Lox    female        group B           bachelor's degree      standard
# pi       male        group A          associate's degree  free/reduced
# dor      male        group C                some college      standard
# nanna    male        group B                some college  free/reduced
# sdds     male        group D                 high school  free/reduced
#
#       test preparation course  math score  reading score  writing score
# Lox                      none          72             72             74
# pi                       none          47             57             44
# dor                      none          76             78             75
# nanna                    none          40             43             39
# sdds                completed          64             64             67

# %%
st_per_all = pd.read_csv("StudentsPerformance1.csv")

# %%
st_per_lubch = st_per_all[st_per.lunch == 'free/reduced']

# %%
st_per_all.mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
st_per_all.var()
# Out:
# math score       229.918998
# reading score    213.165605
# writing score    230.907992
# dtype: float64

# %%
st_per_lubch.mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
st_per_lubch.var()
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
student_stats = pd.read_csv("StudentsPerformance2.csv")

# %%
student_stats[student_stats['parental level of education'].isin(["bachelor's degree", "master's degree"])].head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 2   female        group B             master's degree      standard
# 14  female        group A             master's degree      standard
# 18    male        group C             master's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 2                     none          90             95             93
# 14                    none          50             53             58
# 18               completed          46             42             46
# 24               completed          74             71             80

# %%
student_stats.filter(like='education').head()
# Out:
#   parental level of education
# 0           bachelor's degree
# 1                some college
# 2             master's degree
# 3          associate's degree
# 4                some college
