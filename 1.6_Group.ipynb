# %%
import pandas as pd
dota = pd.read_csv('dota_hero_stats.csv')

# %%
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota.groupby(['attack_type', 'primary_attr']).aggregate('count')
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
import pandas as pd
lupu = pd.read_csv('accountancy.csv')
lupu.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
lupu.groupby(['Type', 'Executor']).aggregate({'Salary': 'mean'})
# Out:
#                    Salary
# Type Executor
# A    Loopa      58.000000
#      Pupa      160.833333
# B    Loopa     145.166667
#      Pupa       77.000000
# C    Loopa     154.333333
#      Pupa       74.500000
# D    Loopa     137.714286
#      Pupa      146.500000
# E    Loopa     164.000000
#      Pupa      131.200000
# F    Loopa     238.000000
#      Pupa      136.250000

# %%
import pandas as pd
concentrations = pd.read_csv('algae1.csv')

# %%
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
mean_concentrations = concentrations.groupby('group').aggregate('max')

# %%
mean_concentrations
# Out:
#                     species       genus   sucrose    alanin   citrate  \
# group
# brown  Saccharina_latissima  Saccharina  6.825467  6.641303  6.423606
# green   Cladophora_gracilis  Cladophora  5.712284  6.881024  6.940588
# red        Palmaria_palmata    Palmaria  0.704580  3.176440  5.573905
#
#         glucose  oleic_acid
# group
# brown  6.013219    6.405165
# green  3.343707    2.829016
# red    3.242090    2.245538

# %%
mean_concentrations = concentrations.groupby('group').agg('max')

# %%
mean_concentrations
# Out:
#                     species       genus   sucrose    alanin   citrate  \
# group
# brown  Saccharina_latissima  Saccharina  6.825467  6.641303  6.423606
# green   Cladophora_gracilis  Cladophora  5.712284  6.881024  6.940588
# red        Palmaria_palmata    Palmaria  0.704580  3.176440  5.573905
#
#         glucose  oleic_acid
# group
# brown  6.013219    6.405165
# green  3.343707    2.829016
# red    3.242090    2.245538

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.9.0'
